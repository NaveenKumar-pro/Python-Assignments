# %% [markdown]
# 1. Explain The key Features of Python that make it a popular choice for programming.
#
# *   Python syntax is clear and readable, similar to English
# *   Python code runs line by line; no need for compilation.
# *   You do not need to declare variable types — Python detects them automatically.
# *   Rich standard libraries and third-party modules.
# *   Predefined Keywords in Python

# %% [markdown]
# 2. Describe the role of predfined keywords in python and provide examples of how they are used in a program.
#
# Predefined keywords (also called reserved words) are special words in Python that have fixed meanings and purposes defined by the language itself.
# You cannot use these words as variable names, function names, or identifiers because Python uses them to define syntax and structure.
#
# 🔹 What are Keywords?
#
# 👉 Keywords are words that Python reserves for specific operations — like making decisions, defining loops, declaring functions, handling exceptions, etc.
#
# 🧾 Examples of Keywords in Python (Python 3.11)
# Category	Examples
# Conditional statements	if, else, elif
# Loops	for, while, break, continue
# Functions & classes	def, class, return, lambda
# Boolean values	True, False, None
# Logical operators	and, or, not
# Variable scope	global, nonlocal
# Exception handling	try, except, finally, raise
# Import & module	import, from, as
# Others	in, is, pass, yield, assert, del
# 🔍 Check All Keywords in Python
#
# You can see the full list of keywords by running:
#
# import keyword
# print(keyword.kwlist)
#
# ⚙️ Examples of How Keywords Are Used
# 1️⃣ Using if, elif, else
# x = 10
#
# if x > 0:
#     print("Positive number")
# elif x == 0:
#     print("Zero")
# else:
#     print("Negative number")
#
#
# Output:
#
# Positive number
#
#
# 🟢 Here, if, elif, and else are decision-making keywords.
#
# 2️⃣ Using for, in
# for i in range(3):
#     print("Hello")
#
#
# Output:
#
# Hello
# Hello
# Hello
#
#
# 🟢 for starts a loop, and in is used to iterate through a sequence.
#
# 3️⃣ Using def, return
# def add(a, b):
#     return a + b
#
# print(add(5, 3))
#
#
# Output:
#
# 8
#
#
# 🟢 def defines a function, and return sends back the result.
#
# 4️⃣ Using try, except
# try:
#     x = 10 / 0
# except ZeroDivisionError:
#     print("Cannot divide by zero!")
#
#
# Output:
#
# Cannot divide by zero!
#
#
# 🟢 These keywords are used for error handling.
#
# 5️⃣ Using class
# class Student:
#     def __init__(self, name):
#         self.name = name
#
# s = Student("Naveen")
# print(s.name)
#
#
# Output:
#
# Naveen
#
#
# 🟢 class is used to define a blueprint for objects.
#
# ✅ Summary
# Purpose	Keyword Example	Use
# Conditional	if, else, elif	Decision making
# Loop	for, while, break	Repetition control
# Function	def, return	Define and return functions
# Boolean/Logic	True, False, and, or, not	Logical operations
# Exception	try, except, finally	Error handling
# Class/Object	class, self	Object-oriented programming
# Misc.	import, as, pass, del	Various special operations
#
# In short:
#
# Predefined keywords form the grammar of Python — they define how programs are structured and executed. Without them, Python code wouldn’t make sense to the interpreter.

# %% [markdown]
# 3. Compare and contrast mutable and immutable objects in python with examples.
#
# *   Mutable Objects**   | Objects whose **contents can be changed** after creation.  |
# *   Immutable Objects** | Objects whose **contents cannot be changed** once created. |

# %% [markdown]
# 4. Discuss the different types of operators in python and examples of how they are used.
# Operator	Description	Example	Output
#
# +	Addition	-------10 + 5 = 15
# -	Subtraction	-----10 - 5	= 5
# *	Multiplication-----	10 * 5	= 50
# /	Division	------10 / 3	= 3.333...
# //	Floor Division	------10 // 3	= 3
# %	Modulus (remainder)	-----10 % 3	= 1
# **	Exponentiation	------2 ** 3	= 8

# %% [markdown]
# 5. Explain the concept of typecasting in python with examples.
# 1. Implicit Typecasting (Automatic Conversion)
#
# 👉 Python automatically converts one data type into another without user intervention.
#
# Example:
# a = 5       # int
# b = 2.5     # float
#
# result = a + b
# print(result)
# print(type(result))
#
# Output:
# 7.5
# <class 'float'>
#
#
# 🟢 Explanation:
# Python automatically converted the integer a into a float so that both operands are of the same type (float).
# This is called implicit typecasting.
#
# 2. Explicit Typecasting (Manual Conversion)
#
# 👉 You manually convert one data type into another using built-in functions like:
#
# int()
#
# float()
#
# str()
#
# bool()
#
# list(), tuple(), etc.
#
# Example 1: Converting float to int
# x = 10.9
# y = int(x)
# print(y)
# print(type(y))
#
#
# Output:
#
# 10
# <class 'int'>
#
#
# 🟠 Decimal part is removed, not rounded.
#
# Example 2: String to Integer
# s = "123"
# num = int(s)
# print(num + 5)
# print(type(num))
#
#
# Output:
#
# 128
# <class 'int'>
#
#
# 🟢 String "123" is converted into integer 123.
#
# Example 3: Integer to String
# n = 45
# s = str(n)
# print("The number is " + s)
#
#
# Output:
#
# The number is 45

# %% [markdown]
# 6. How do conditional statements work in python ? Illustrates with examples
#
# Conditional statements are used to make decisions in your code — they allow your program to execute different blocks of code based on certain conditions.
#
# In simple words:
#
# “If a condition is true, do something; otherwise, do something else.”
#
# 🔹 Main Conditional Statements in Python
#
# if statement
#
# if-else statement
#
# if-elif-else ladder
#
# Nested if statement
#
# 1️⃣ if Statement
#
# 👉 Used to check a condition. If the condition is True, the block inside if executes.
#
# age = 18
#
# if age >= 18:
#     print("You are eligible to vote.")
#
#
# Output:
#
# You are eligible to vote.
#
#
# 🟢 Since age >= 18 is True, the statement runs.
#
# 2️⃣ if-else Statement
#
# 👉 Runs one block if condition is True, otherwise another block.
#
# age = 16
#
# if age >= 18:
#     print("You are eligible to vote.")
# else:
#     print("You are not eligible to vote.")
#
#
# Output:
#
# You are not eligible to vote.
#
#
# 🟠 Since the condition is False, the else block runs.
#
# 3️⃣ if-elif-else Ladder
#
# 👉 Used when you have multiple conditions to check.
#
# marks = 75
#
# if marks >= 90:
#     print("Grade: A+")
# elif marks >= 75:
#     print("Grade: A")
# elif marks >= 60:
#     print("Grade: B")
# else:
#     print("Grade: C")
#
#
# Output:
#
# Grade: A
#
#
# 🟢 Python checks each condition from top to bottom and executes the first one that’s True.
#
# 4️⃣ Nested if Statement
#
# 👉 An if statement inside another if statement.
#
# num = 10
#
# if num > 0:
#     if num % 2 == 0:
#         print("Positive and Even number")
#     else:
#         print("Positive but Odd number")
# else:
#     print("Negative number")
#
#
# Output:
#
# Positive and Even number
#
#
# 🟢 Both conditions are checked — first whether the number is positive, then whether it’s even.

# %% [markdown]
# 7. Describe the Different types of loops in python and their use cases with examples.
#
# Types of Loops in Python
#
# Loops are used in Python to repeat a block of code multiple times until a condition is met or a sequence ends.
#
# There are two main types of loops in Python:
#
# for loop
#
# while loop
#
# Additionally, Python supports loop control statements like break, continue, and pass.
#
# 🟢 1️⃣ for Loop
#
# 👉 Used to iterate over a sequence (like a list, tuple, string, or range).
#
# Syntax:
#
# for variable in sequence:
#     # code block
#
# ✅ Example 1: Print numbers from 1 to 5
# for i in range(1, 6):
#     print(i)
#
#
# Output:
#
# 1
# 2
# 3
# 4
# 5
#
#
# 🟢 range(1, 6) generates numbers from 1 to 5.
#
# ✅ Example 2: Iterate over a list
# fruits = ["apple", "banana", "mango"]
#
# for fruit in fruits:
#     print(fruit)
#
#
# Output:
#
# apple
# banana
# mango
#
#
# 📘 Use case: When you want to loop through a collection of items (lists, strings, etc.).
#
# 🔵 2️⃣ while Loop
#
# 👉 Executes a block of code as long as a condition is True.
#
# Syntax:
#
# while condition:
#     # code block
#
# ✅ Example 1: Print numbers from 1 to 5
# i = 1
# while i <= 5:
#     print(i)
#     i += 1
#
#
# Output:
#
# 1
# 2
# 3
# 4
# 5
#
#
# 🟠 If the condition becomes False, the loop stops.
#
# ✅ Example 2: Countdown
# count = 5
#
# while count > 0:
#     print(count)
#     count -= 1
#
#
# Output:
#
# 5
# 4
# 3
# 2
# 1
#
#
# 📘 Use case: When you don’t know exactly how many times you need to loop — you continue until a certain condition is met.
#
# 🟣 3️⃣ Loop Control Statements
#
# These statements control the behavior of loops.
#
# Statement	Description	Example
# break	Stops the loop completely	Stops when a certain condition is met
# continue	Skips the current iteration and continues with the next	Skip odd numbers
# pass	Does nothing (placeholder)	Used when code is not ready yet
# ✅ Example: break
# for i in range(1, 10):
#     if i == 5:
#         break
#     print(i)
#
#
# Output:
#
# 1
# 2
# 3
# 4
#
#
# Stops the loop when i == 5.
#
# ✅ Example: continue
# for i in range(1, 6):
#     if i == 3:
#         continue
#     print(i)
#
#
# Output:
#
# 1
# 2
# 4
# 5
#
#
# Skips printing 3.
#
# ✅ Example: pass
# for i in range(5):
#     pass  # Placeholder for future code
#
#
# 🟢 Used when you want a loop but don’t want to execute any code inside it (yet).
